# %%
pip install facebook-scraper
# Out:
# ...
#      |████████████████████████████████| 1.2MB 7.2MB/s
# ...
#      |████████████████████████████████| 81kB 11.6MB/s
# ...
#   Created wheel for pyppeteer: filename=pyppeteer-0.0.25-cp36-none-any.whl size=78362 sha256=afaf7d5f206d21a5fb0a16bbe2e255a6bb02907a44235254fb5b2587176289c0
#   Stored in directory: /root/.cache/pip/wheels/34/e0/5d/070e22eceecf7ecd5fa4b86bbc18c1c7d0b90e02e9b57f35eb
# ...
#   Created wheel for parse: filename=parse-1.12.1-cp36-none-any.whl size=22342 sha256=cd5cc1b640db3f4ca6850d68f8cddb86ac08bd23f249675f2130c5fe428a77e2
#   Stored in directory: /root/.cache/pip/wheels/16/f1/d5/72f7e2c22ab3d106bb6f7d727552b5e027b832284f4704b106
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=d3fa51bafc2c2f31090964a6f526bcc7fb1b39442dd2e6af3f16bc6c04f79ced
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built pyppeteer parse fake-useragent
# ...

# %%
from facebook_scraper import get_posts
postarr=[]
for post in get_posts('oldLentach', pages=10000):
     postarr.append(tuple(post['text'],)

# %%
import pandas as pd

# %%
df = pd.DataFrame(postarr, columns=['text'])

# %%
df
# Out:
#                                                    text
# 0     Замглавы ФСИН подал в отставку, пишут СМИ. Ран...
# 1     Группу экспертов, которые нашли сатанизм и мас...
# 2     В Тбилиси спецназ разогнал протестующих, котор...
# 3     Законопроект об ограничении доли иностранного ...
# 4     Названы регионы с самым быстрым ростом зарплат...
# ...                                                 ...
# 3469  В Латвии безрукий молодой человек Гатис Цаунит...
# 3470  Правительство собирается передать гору бабла и...
# 3471  Сегодня ночью в средней полосе России (в том ч...
# 3472  Путин сегодня в Душанбе рассказал журналистам,...
# 3473  Россия введет защитные меры в отношении Украин...
#
# [3474 rows x 1 columns]

# %%
df.to_csv('Lentach.csv', index=False)

# %%
wall_post_text

# %%
from bs4 import BeautifulSoup

import requests
from datetime import date, timedelta

# %%
from concurrent.futures import ThreadPoolExecutor as PoolExecutor
import http.client
import socket
toker = []
def get_it():
        # always set a timeout when you connect to an external server

        

    r  = requests.get("https://vk.com/wall-29534144?offset=40&own=1"   )
    #r  = requests.get("https://www.sports.ru/stat/news/2000/12/10.html",   )
    data = r.text
    print(data)
    soup = BeautifulSoup(data)
  #  print(soup)

    inputTag = soup.findAll(attrs={"class" : "content"})
    print(inputTag)
    for link in inputTag:
                toker.append(link.text)

# %%
get_it()
# Out:
#             <!DOCTYPE html>
#       <html class="vk vk_js_no vk_1x vk_flex_no r d h  vk_appAuth_no n vk_old ">
#       <head>
#               <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#         <meta name="format-detection" content="telephone=no" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <meta name="MobileOptimized" content="176" />
#         <meta name="HandheldFriendly" content="True" />
#         <base id="base">
#         <meta name="robots" content="noindex,nofollow" />
#         <link rel="shortcut icon" href="/images/icons/favicons/fav_logo.ico?8"></link>
#             <meta name="theme-color" content="#5181b8" />
#     <link rel="icon" type="image/png" sizes="32x32" href="/images/icons/pwa/favicon_32.png?8">
#     <link rel="apple-touch-icon" href="/images/icons/pwa/apple/default.png?8">
# ...

# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 911kB 4.8MB/s
# ...

# %%
from selenium.webdriver import Chrome

# %%
webdriver = "path_to_installed_driver_location"

driver = Chrome(webdriver)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ...

# %%
toker
# Out:
# []
